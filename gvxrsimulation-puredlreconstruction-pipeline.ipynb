# %%
import os
import sys
import torch
import gc

# 1. Clear GPU memory cache
gc.collect()
torch.cuda.empty_cache()
print(f"🚀 Device: {torch.cuda.get_device_name(0)} | Free VRAM: {torch.cuda.mem_get_info()[0] / (1024**3):.2f} GB")

# 2. Clone or Pull Latest Code from GitHub
REPO_DIR = "/kaggle/working/pipeline_repo"

if not os.path.exists(REPO_DIR):
    print("Cloning repository from GitHub...")
    # !git clone -b sequential-pipeline https://github.com/kitretsu2809/gVXRsimulation_PureDLReconstruction_Pipeline.git {REPO_DIR}
else:
    print("Pulling latest updates from GitHub...")
    # !cd {REPO_DIR} && git pull origin sequential-pipeline

# 3. Locate the Dataset (.npz files) from Kaggle Input
DATASET_DIR = None
for root, dirs, files in os.walk("/kaggle/input"):
    if any(f.endswith(".npz") for f in files):
        DATASET_DIR = root
        break

print(f"📁 Using dataset from: {DATASET_DIR}")

# 4. Run Training with your Latest GitHub Code!
import runpy
sys.argv = [
    "02_train_pure_dl.py",
    "--dataset-path", DATASET_DIR,
    "--epochs", "50",
    "--batch-size", "4",
    "--learning-rate", "1e-3"
]

train_script = os.path.join(REPO_DIR, "scripts", "pure_dl", "02_train_pure_dl.py")
runpy.run_path(train_script, run_name="__main__")
# Out:
# 🚀 Device: Tesla T4 | Free VRAM: 6.54 GB
# Pulling latest updates from GitHub...
# From https://github.com/kitretsu2809/gVXRsimulation_PureDLReconstruction_Pipeline
#  * branch            sequential-pipeline -> FETCH_HEAD
# Already up to date.
# 📁 Using dataset from: /kaggle/input/datasets/kitretsu2809/pure-dl-reconstruction
# Discovered 8 dataset files for Big Data training.
# Loading cube_Ti_standard_auto.npz...
# Loading lizard_Ti_standard_auto.npz...
# Loading void_sphere_Ti_standard_auto.npz...
# Loading void_defected_box_Ti_standard_auto.npz...
# Loading FINAL30_Ti_standard_auto.npz...
# Loading torus_Ti_standard_auto.npz...
# Loading void_cube_Ti_standard_auto.npz...
# Loading void_pipe_Ti_standard_auto.npz...
# Initializing PureDLPipeline...
# /kaggle/working/pipeline_repo/scripts/pure_dl/02_train_pure_dl.py:207: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
# ...
